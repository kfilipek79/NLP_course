# %% [markdown]
# # ELMo

# %%
import tensorflow as tf
import tensorflow_hub as hub

elmo = hub.load("https://tfhub.dev/google/elmo/3")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 2
#       1 import tensorflow as tf
# ----> 2 import tensorflow_hub as hub
#       4 elmo = hub.load("https://tfhub.dev/google/elmo/3")
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow_hub/__init__.py:90
#      85 _ensure_tf_install()
#      88 # pylint: disable=g-import-not-at-top
#      89 # pylint: disable=g-bad-import-order
# ---> 90 from tensorflow_hub.estimator import LatestModuleExporter
#      91 from tensorflow_hub.estimator import register_module_for_export
#      92 from tensorflow_hub.feature_column_v2 import text_embedding_column_v2
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow_hub/estimator.py:21
#      19 from absl import logging
#      20 import tensorflow as tf
# ...

# %%
# !pip install keras
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
